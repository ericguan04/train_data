# %%
import pandas as pd

df = pd.read_csv("MTA_Subway_Origin-Destination_Ridership_Estimate__2024_20250225.csv")

# %%
df.head()
# Out:
#    Year  Month Day of Week  Hour of Day               Timestamp  \
# 0  2024      9     Tuesday           14  09/03/2024 02:00:00 PM
# 1  2024      9     Tuesday           14  09/03/2024 02:00:00 PM
# 2  2024      9     Tuesday           14  09/03/2024 02:00:00 PM
# 3  2024      9     Tuesday           14  09/03/2024 02:00:00 PM
# 4  2024      9     Tuesday           14  09/03/2024 02:00:00 PM
#
#    Origin Station Complex ID Origin Station Complex Name  Origin Latitude  \
# 0                        355           Winthrop St (2,5)        40.656652
# 1                        395                  103 St (6)        40.790600
# 2                        405                   23 St (6)        40.739864
# 3                        608         4 Av (F,G)/9 St (R)        40.670559
# 4                        141                 Park Pl (S)        40.674772
#
#    Origin Longitude  Destination Station Complex ID  \
# 0        -73.950200                             185
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1826409 entries, 0 to 1826408
# Data columns (total 16 columns):
#  #   Column                            Dtype
# ---  ------                            -----
#  0   Year                              int64
#  1   Month                             int64
#  2   Day of Week                       object
#  3   Hour of Day                       int64
#  4   Timestamp                         object
#  5   Origin Station Complex ID         int64
#  6   Origin Station Complex Name       object
#  7   Origin Latitude                   float64
#  8   Origin Longitude                  float64
#  9   Destination Station Complex ID    int64
#  10  Destination Station Complex Name  object
#  11  Destination Latitude              float64
#  12  Destination Longitude             float64
#  13  Estimated Average Ridership       float64
#  14  Origin Point                      object
#  15  Destination Point                 object
# ...

# %%
df.describe()
# Out:
#             Year      Month   Hour of Day  Origin Station Complex ID  \
# count  1826409.0  1826409.0  1.826409e+06               1.826409e+06
# mean      2024.0        9.0  1.503020e+01               2.916973e+02
# std          0.0        0.0  8.127700e-01               1.789383e+02
# min       2024.0        9.0  1.400000e+01               1.000000e+00
# 25%       2024.0        9.0  1.400000e+01               1.510000e+02
# 50%       2024.0        9.0  1.500000e+01               2.840000e+02
# 75%       2024.0        9.0  1.600000e+01               4.070000e+02
# max       2024.0        9.0  1.600000e+01               6.360000e+02
#
#        Origin Latitude  Origin Longitude  Destination Station Complex ID  \
# count     1.826409e+06      1.826409e+06                    1.826409e+06
# mean      4.073398e+01     -7.394537e+01                    2.877802e+02
# std       6.999819e-02      5.174968e-02                    1.775083e+02
# ...
