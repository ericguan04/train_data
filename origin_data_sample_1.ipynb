# %% [markdown]
# # Data Exploration
#
# * `MTA Subway Origin Destination Ridership 2024` Dataset (Sample)
# * `MTA Subway Stations and Complexes 2025` Dataset
#
# * **Origin-Destination Filter:** September 2024, 2 - 4PM

# %%
import pandas as pd

ridership_df = pd.read_csv("MTA_Subway_Origin-Destination_Ridership_Estimate__2024_20250225.csv")

# %%
ridership_df.tail()
# Out:
#          Year  Month Day of Week  Hour of Day               Timestamp  \
# 1826404  2024      9    Thursday           16  09/05/2024 04:00:00 PM
# 1826405  2024      9    Thursday           16  09/05/2024 04:00:00 PM
# 1826406  2024      9    Thursday           16  09/05/2024 04:00:00 PM
# 1826407  2024      9    Thursday           16  09/05/2024 04:00:00 PM
# 1826408  2024      9    Thursday           16  09/05/2024 04:00:00 PM
#
#          Origin Station Complex ID      Origin Station Complex Name  \
# 1826404                        610  Grand Central-42 St (S,4,5,6,7)
# 1826405                        450          103 St-Corona Plaza (7)
# 1826406                        440                     116 St (2,3)
# 1826407                        438                     135 St (2,3)
# 1826408                        432                Prospect Av (2,5)
#
#          Origin Latitude  Origin Longitude  Destination Station Complex ID  \
# 1826404        40.751992        -73.977359                             109
# 1826405        40.749865        -73.862700                             244
# 1826406        40.802098        -73.949625                             307
# 1826407        40.814229        -73.940770                             262
# 1826408        40.819585        -73.901770                             308
#
#         Destination Station Complex Name  Destination Latitude  \
# 1826404                Fresh Pond Rd (M)             40.706186
# 1826405                    Ditmas Av (F)             40.636119
# 1826406   116 St-Columbia University (1)             40.807722
# 1826407                      67 Av (M,R)             40.726523
# 1826408      Cathedral Pkwy (110 St) (1)             40.803967
#
#          Destination Longitude  Estimated Average Ridership  \
# 1826404             -73.895877                       8.9447
# 1826405             -73.978172                       0.6915
# 1826406             -73.964110                       2.7550
# 1826407             -73.852719                       0.5960
# 1826408             -73.966847                       0.3313
#
#                          Origin Point             Destination Point
# 1826404  POINT (-73.977359 40.751992)  POINT (-73.895877 40.706186)
# 1826405    POINT (-73.8627 40.749865)  POINT (-73.978172 40.636119)
# 1826406  POINT (-73.949625 40.802098)   POINT (-73.96411 40.807722)
# 1826407   POINT (-73.94077 40.814229)  POINT (-73.852719 40.726523)
# 1826408   POINT (-73.90177 40.819585)  POINT (-73.966847 40.803967)

# %%
ridership_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1826409 entries, 0 to 1826408
# Data columns (total 16 columns):
#  #   Column                            Dtype
# ---  ------                            -----
#  0   Year                              int64
#  1   Month                             int64
#  2   Day of Week                       object
#  3   Hour of Day                       int64
#  4   Timestamp                         object
#  5   Origin Station Complex ID         int64
#  6   Origin Station Complex Name       object
#  7   Origin Latitude                   float64
#  8   Origin Longitude                  float64
#  9   Destination Station Complex ID    int64
#  10  Destination Station Complex Name  object
#  11  Destination Latitude              float64
#  12  Destination Longitude             float64
#  13  Estimated Average Ridership       float64
#  14  Origin Point                      object
#  15  Destination Point                 object
# dtypes: float64(5), int64(5), object(6)
# memory usage: 223.0+ MB

# %%
ridership_df["Origin Station Complex Name"].unique()
# Out:
# array(['Winthrop St (2,5)', '103 St (6)', '23 St (6)',
#        '4 Av (F,G)/9 St (R)', 'Park Pl (S)', '145 St (A,C,B,D)',
#        'Fordham Rd (B,D)',
#        '74-Broadway (7)/Jackson Hts-Roosevelt Av (E,F,M,R)',
#        'Court St (R)/Borough Hall (2,3,4,5)', 'Prospect Av (R)',
#        'Avenue H (Q)', '181 St (A)', '135 St (C,B)', 'East Broadway (F)',
#        '238 St (1)', 'Queensboro Plaza (7,N,W)', '5 Av/59 St (N,R,W)',
#        'New Utrecht Av (N)/62 St (D)', '25 St (R)', '103 St (C,B)',
#        'W 4 St-Wash Sq (A,C,E,B,D,F,M)', 'Tremont Av (B,D)', '57 St (F)',
#        'Grand St (B,D)', 'Elmhurst Av (M,R)', 'Steinway St (M,R)',
#        'Clinton-Washington Avs (G)', '23 St (1)', '77 St (6)',
#        'Junction Blvd (7)', '52 St (7)', '161 St-Yankee Stadium (B,D,4)',
#        'Grand Central-42 St (S,4,5,6,7)',
#        '59 St-Columbus Circle (A,B,C,D,1)',
#        'Atlantic Av-Barclays Ctr (B,D,N,Q,R,2,3,4,5)',
#        'Jay St-MetroTech (A,C,F,R)', '46 St-Bliss St (7)',
#        'Nostrand Av (A,C)', 'Parsons Blvd (F)',
#        'Delancey St (F)/Essex St (J,M,Z)', '20 Av (N)', 'Morgan Av (L)',
#        '96 St (C,B)', 'Spring St (C,E)', 'Grant Av (A)', 'Fulton St (G)',
#        '86 St (1)', 'Fordham Rd (4)', '72 St (Q)',
#        '34 St-Herald Sq (B,D,F,M,N,Q,R,W)',
#        'Franklin Av (2,3,4,5)/Botanic Garden (S)',
#        'Grand Army Plaza (2,3)', '90 St-Elmhurst Av (7)', '86 St (Q)',
#        '137 St-City College (1)', 'Bedford Park Blvd (B,D)',
#        'Sheepshead Bay (B,Q)', 'Lorimer St (M,J)', '116 St (2,3)',
#        'Marcy Av (M,J,Z)', 'Northern Blvd (M,R)',
#        'Marble Hill-225 St (1)', '145 St (1)', '96 St (1,2,3)',
#        '18 St (1)', '33 St (6)', 'Vernon Blvd-Jackson Av (7)',
#        'Fulton St (A,C,J,Z,2,3,4,5)', '30 Av (N,W)',
#        'Myrtle-Willoughby Avs (G)', 'Junius St (3)',
#        '149 St-Grand Concourse (2,4,5)', '23 St (R,W)', '121 St (J,Z)',
#        '104 St (A)', '72 St (1,2,3)', '86 St (4,5,6)',
#        'Broadway-Lafayette St (B,D,F,M)/Bleecker St (6)',
#        'Lorimer St (L)/Metropolitan Av (G)', 'Chauncey St (J,Z)',
#        'High St (A,C)', 'Bergen St (F,G)', 'Sterling St (2,5)',
#        'Church Av (2,5)', 'Mosholu Pkwy (4)', 'Smith-9 Sts (F,G)',
#        '53 St (R)', '77 St (R)', 'Beverly Rd (2,5)', 'Rockaway Av (C)',
#        '47-50 Sts-Rockefeller Ctr (B,D,F,M)', '46 St (M,R)',
#        'Queens Plaza (E,M,R)', 'Nassau Av (G)', 'Parkchester (6)',
#        'Burnside Av (4)', '167 St (4)', 'Spring St (6)',
#        'West Farms Sq-E Tremont Av (2,5)', 'Prospect Av (2,5)',
#        '14 St (F,M,1,2,3)/6 Av (L)', 'Broadway (N,W)', 'Church Av (B,Q)',
#        '155 St (C)', 'Bowling Green (4,5)', '174 St (2,5)',
#        'Hunters Point Av (7)', '57 St-7 Av (N,Q,R,W)', 'City Hall (R,W)',
#        'Kings Hwy (B,Q)', 'Halsey St (L)', 'Far Rockaway-Mott Av (A)',
#        '182-183 Sts (B,D)', 'Briarwood (E,F)', 'Flushing Av (G)',
#        'Rockaway Av (3)', '68 St-Hunter College (6)', 'E 180 St (2,5)',
#        'Cortelyou Rd (Q)', '170 St (B,D)', '50 St (1)', 'Clark St (2,3)',
#        'St Lawrence Av (6)', '168 St (A,C,1)', 'Bay Ridge Av (R)',
#        '88 St (A)', '125 St (4,5,6)',
#        'Brooklyn Bridge-City Hall (4,5,6)/Chambers St (J,Z)',
#        '28 St (R,W)', '36 St (D,N,R)',
#        'Chambers St (A,C)/WTC (E)/Park Pl (2,3)/Cortlandt (R,W)',
#        'Woodhaven Blvd (M,R)', '116 St-Columbia University (1)',
#        'Chambers St (1,2,3)', '1 Av (L)', 'Hoyt-Schermerhorn Sts (A,C,G)',
#        '2 Av (F)', '125 St (A,C,B,D)',
#        'Central Park North (110 St) (2,3)', '61 St-Woodside (7)',
#        'Lexington Av-53 St (E,M)/51 St (6)', 'Carroll St (F,G)',
#        'Howard Beach-JFK Airport (A)', '21 St (G)', '191 St (1)',
#        '15 St-Prospect Park (F,G)', '40 St-Lowery St (7)',
#        'Prince St (R,W)', '59 St (N,R)', 'East 105 St (L)',
#        'Utica Av (A,C)', 'Greenpoint Av (G)', 'Houston St (1)',
#        'New Lots Av (3)', 'Flatbush Av-Brooklyn College (2,5)',
#        'Jackson Av (2,5)', 'Lexington Av (N,R,W)/59 St (4,5,6)',
#        '7 Av (B,Q)', 'Avenue M (Q)', '7 Av (F,G)', 'Harlem-148 St (3)',
#        'Central Av (M)', '21 St-Queensbridge (F)', 'Bedford Av (L)',
#        'Jamaica Center-Parsons/Archer (E,J,Z)', '8 St-NYU (R,W)',
#        'Myrtle Av (M,J,Z)', 'Graham Av (L)',
#        'Cathedral Pkwy (110 St) (1)', 'Wall St (2,3)',
#        'Kingsbridge Rd (4)', '14 St (A,C,E)/8 Av (L)', 'Montrose Av (L)',
#        'Myrtle-Wyckoff Avs (L,M)', 'Pelham Bay Park (6)',
#        'Astoria-Ditmars Blvd (N,W)', 'DeKalb Av (B,Q,R)', '50 St (C,E)',
#        'Brighton Beach (B,Q)', 'Bedford Park Blvd-Lehman College (4)',
#        'Astoria Blvd (N,W)', 'Coney Island-Stillwell Av (D,F,N,Q)',
#        'Avenue P (F)', '36 St (M,R)', 'E 149 St (6)',
#        '33 St-Rawson St (7)', 'Ralph Av (C)', 'Avenue N (F)',
#        '167 St (B,D)', 'Roosevelt Island (F)',
#        'Sutphin Blvd-Archer Av-JFK Airport (E,J,Z)', '96 St (6)',
#        'Times Sq-42 St (N,Q,R,W,S,1,2,3,7)/42 St (A,C,E)',
#        'Canal St (J,N,Q,R,W,Z,6)', 'Franklin Av (C,S)',
#        'South Ferry (1)/Whitehall St (R,W)', '50 St (D)',
#        'Gun Hill Rd (5)', 'Beverley Rd (Q)', '9 Av (D)',
#        '34 St-Penn Station (A,C,E)', 'Beach 67 St (A)', '23 St (C,E)',
#        'Forest Hills-71 Av (E,F,M,R)', 'Sutter Av (L)',
#        '34 St-Hudson Yards (7)', 'DeKalb Av (L)', 'Liberty Av (C)',
#        '3 Av-149 St (2,5)', '145 St (3)', 'Hoyt St (2,3)',
#        'Whitlock Av (6)', 'Union St (R)', '157 St (1)',
#        'Jefferson St (L)', 'Lexington Av/63 St (F,Q)',
#        '34 St-Penn Station (1,2,3)', 'Christopher St-Sheridan Sq (1)',
#        'Brook Av (6)', '3 Av (L)', 'Bay Pkwy (F)', '231 St (1)',
#        'Westchester Sq-E Tremont Av (6)', 'Flushing-Main St (7)',
#        '14 St-Union Sq (L,N,Q,R,W,4,5,6)', 'Neck Rd (Q)',
#        'Newkirk Plaza (B,Q)', 'Kingston-Throop Avs (C)',
#        'Kew Gardens-Union Tpke (E,F)', 'Inwood-207 St (A)',
#        'Aqueduct Racetrack (A)', 'Broad Channel (A,S)',
#        'Eastchester-Dyre Av (5)', 'Mets-Willets Point (7)',
#        '81 St-Museum of Natural History (C,B)', 'Kings Hwy (N)',
#        'Bowery (J,Z)', 'Grand St (L)', 'Lafayette Av (C)', '7 Av (E,B,D)',
#        'Newkirk Av-Little Haiti (2,5)', 'Livonia Av (L)', 'Zerega Av (6)',
#        'Crown Hts-Utica Av (3,4)', '79 St (D)', 'Canal St (1)',
#        '3 Av-138 St (6)', '170 St (4)', '138 St-Grand Concourse (4,5)',
#        '125 St (2,3)', 'Bay Pkwy (N)', '28 St (6)', '86 St (C,B)',
#        'Canarsie-Rockaway Pkwy (L)', '169 St (F)', '175 St (A)',
#        '23 St (F,M)', '116 St (6)', 'Court Sq (E,G,M,7)',
#        'WTC Cortlandt (1)', 'Norwood Av (J,Z)', 'Canal St (A,C,E)',
#        'Wakefield-241 St (2)', 'Bryant Pk (B,D,F,M)/5 Av (7)',
#        'Kingsbridge Rd (B,D)', 'Astor Pl (6)', 'Avenue X (F)',
#        'Wall St (4,5)', 'Classon Av (G)', 'Fort Hamilton Pkwy (N)',
#        'Church Av (F,G)', '96 St (Q)', '190 St (A)', '79 St (1)',
#        'Saratoga Av (3)', 'Prospect Park (B,Q,S)', 'Jamaica-179 St (F)',
#        'Freeman St (2,5)', '36 Av (N,W)', '8 Av (N)', '86 St (N)',
#        'Beach 25 St (A)', 'Sutphin Blvd (F)', '75 Av (E,F)',
#        '63 Dr-Rego Park (M,R)', 'Bay 50 St (D)', 'Van Siclen Av (C)',
#        'Parkside Av (Q)', 'Middle Village-Metropolitan Av (M)',
#        "E 143 St-St Mary's St (6)", 'Wilson Av (L)', 'Rockaway Blvd (A)',
#        'York St (F)', 'Kingston Av (3)', '49 St (N,R,W)',
#        'Nereid Av (2,5)', '225 St (2,5)', 'Castle Hill Av (6)',
#        'Van Siclen Av (J,Z)', '65 St (M,R)', 'Nevins St (2,3,4,5)',
#        'Jamaica-Van Wyck (E)', 'Alabama Av (J)', 'Shepherd Av (C)',
#        'Bergen St (2,3)', 'Dyckman St (1)', 'Morris Park (5)',
#        'Rockaway Park-Beach 116 St (A,S)', 'Euclid Av (A,C)',
#        'Fort Hamilton Pkwy (F,G)', '174-175 Sts (B,D)', '155 St (B,D)',
#        'Grand Av-Newtown (M,R)', '110 St (6)', 'Norwood-205 St (D)',
#        '125 St (1)', 'Avenue U (Q)', 'Avenue J (Q)',
#        'Cathedral Pkwy (110 St) (C,B)', '135 St (2,3)',
#        'Broadway Junction (A,C,J,L,Z)', 'New Lots Av (L)',
#        'Allerton Av (2,5)', 'Gun Hill Rd (2,5)', '69 St (7)',
#        '72 St (C,B)', 'Buhre Av (6)', '67 Av (M,R)',
#        'Fort Hamilton Pkwy (D)', 'Bay Pkwy (D)', 'Pelham Pkwy (2,5)',
#        'Beach 36 St (A)', 'President St-Medgar Evers College (2,5)',
#        'Longwood Av (6)', '75 St-Elderts Ln (J,Z)', '103 St (1)',
#        'Woodlawn (4)', 'Flushing Av (M,J)', 'Broadway (G)',
#        '233 St (2,5)', 'Knickerbocker Av (M)', '55 St (D)', '20 Av (D)',
#        '66 St-Lincoln Center (1)', 'Intervale Av (2,5)',
#        'Bedford-Nostrand Avs (G)', 'Halsey St (J)', 'Hewes St (M,J)',
#        '25 Av (D)', 'Nostrand Av (3)', 'Bushwick Av-Aberdeen St (L)',
#        '82 St-Jackson Hts (7)', 'Hunts Point Av (6)', 'Simpson St (2,5)',
#        '104 St (J,Z)', '80 St (A)', 'Ozone Park-Lefferts Blvd (A)',
#        'Baychester Av (5)', 'Rector St (R,W)', '176 St (4)', '45 St (R)',
#        '86 St (R)', 'Kosciuszko St (J)', '111 St (7)', '18 Av (F)',
#        'Crescent St (J,Z)', '116 St (C,B)', 'Elder Av (6)',
#        'Gates Av (J,Z)', '85 St-Forest Pkwy (J)', '28 St (1)',
#        'Dyckman St (A)', 'Ditmas Av (F)', '219 St (2,5)',
#        'Beach 60 St (A)', 'Van Siclen Av (3)', 'Broad St (J,Z)',
#        'Van Cortlandt Park-242 St (1)', '39 Av-Dutch Kills (N,W)',
#        '207 St (1)', 'Bay Ridge-95 St (R)', '5 Av/53 St (E,M)',
#        'Beach 98 St (A,S)', 'Cypress Av (6)', '111 St (J)',
#        'Avenue U (N)', '181 St (1)', 'Middletown Rd (6)',
#        'Clinton-Washington Avs (C)', 'Franklin St (1)',
#        'Pennsylvania Av (3)', 'Bronx Park East (2,5)',
#        'Morrison Av-Soundview (6)', 'W 8 St-NY Aquarium (F,Q)',
#        'Pelham Pkwy (5)', '103 St-Corona Plaza (7)', '111 St (A)',
#        'Mt Eden Av (4)', 'Ocean Pkwy (Q)', 'Rector St (1)',
#        'Woodhaven Blvd (J,Z)', '18 Av (D)', 'Kings Hwy (F)', '71 St (D)',
#        '18 Av (N)', '183 St (4)', 'Neptune Av (F)', 'Avenue I (F)',
#        'Forest Av (M)', 'Aqueduct-N Conduit Av (A)', 'Cleveland St (J)',
#        '163 St-Amsterdam Av (C)', 'Atlantic Av (L)', 'Burke Av (2,5)',
#        'Sutter Av-Rutland Rd (3)', 'Fresh Pond Rd (M)', '215 St (1)',
#        'Beach 44 St (A)', 'Eastern Pkwy-Brooklyn Museum (2,3)',
#        'Avenue U (F)', 'Cypress Hills (J)', 'Seneca Av (M)',
#        'Beach 105 St (A,S)', 'Beach 90 St (A,S)'], dtype=object)

# %%
station_df = pd.read_csv("MTA_Subway_Stations_and_Complexes_20250225.csv")

# %%
# Helper function to filter MTA stations by ID
def filter_stations_by_id(station_df, station_ids):
    return station_df[station_df["Complex ID"].isin(station_ids)]

# Hunter, Medgar Evers, City College
# NYU, Columbia
stations_of_interest = [399, 626, 305, 16, 307]
filtered_stations_df = filter_stations_by_id(station_df, stations_of_interest)
filtered_stations_df
# Out:
#      Complex ID  Is Complex  Number Of Stations In Complex  \
# 1           399       False                              1
# 105         626        True                              2
# 141         305       False                              1
# 143         307       False                              1
# 345          16       False                              1
#
#                                            Stop Name Display Name  \
# 1                               68 St-Hunter College          (6)
# 105  Franklin Av-Medgar Evers College/Botanic Garden  (2,3,4,5,S)
# 141                              137 St-City College          (1)
# 143                       116 St-Columbia University          (1)
# 345                                         8 St-NYU        (R,W)
#
#                             Constituent Station Names Station IDs  \
# 1                                68 St-Hunter College         399
# 105  Botanic Garden; Franklin Av-Medgar Evers College    142; 342
# 141                               137 St-City College         305
# 143                        116 St-Columbia University         307
# 345                                          8 St-NYU          16
#
#     GTFS Stop IDs Borough    CBD Daytime Routes    Structure Type   Latitude  \
# 1             628       M  False              6            Subway  40.768141
# 105      239; S04      Bk  False      2 3 4 5 S  Open Cut; Subway  40.670513
# 141           115       M  False              1            Subway  40.822008
# 143           117       M  False              1            Subway  40.807722
# 345           R21       M   True            R W            Subway  40.730328
#
#      Longitude  ADA ADA Notes
# 1   -73.963870    1       NaN
# 105 -73.958688    0       NaN
# 141 -73.953676    0       NaN
# 143 -73.964110    0       NaN
# 345 -73.992629    0       NaN

# %% [markdown]
# # Data Visualziation

# %% [markdown]
# Results indicate that there are many intermediate stations that people switch to in order to get to their place of residence. We may need to identify these particular stations and trace them further.

# %%
# Helper function to get the top destinations from a given station
def top_station_destinations(origin_station_id, top_n=5):
    origin_df = ridership_df[ridership_df["Origin Station Complex ID"] == origin_station_id]
    top_destinations = origin_df.groupby("Destination Station Complex Name").size().sort_values(ascending=False).head(top_n)
    return top_destinations

# %%
# September, 2-4PM - assumption is that this is the time when students are most likely to be traveling home
# Hunter Origin Station
top_station_destinations(399, top_n=5)
# Out:
# Destination Station Complex Name
# 103 St-Corona Plaza (7)    21
# Zerega Av (6)              21
# 1 Av (L)                   21
# Wall St (2,3)              21
# Wall St (4,5)              21
# dtype: int64

# %%
import folium

# Helper function to visualize the top destinations from a given station
def origin_destination_visualizer(origin_station_id, top_n = 5):

    # Get ridership data for the origin station and group by destination
    origin_df = ridership_df[ridership_df["Origin Station Complex ID"] == origin_station_id]
    grouped_origin_df = origin_df.groupby("Destination Station Complex ID")

    # Get origin station information
    origin_station = origin_df.iloc[0]
    origin_lat = origin_station["Origin Latitude"]
    origin_lon = origin_station["Origin Longitude"]
    origin_name = origin_station["Origin Station Complex Name"]

    # Create a Folium map centered at the origin station
    m = folium.Map(location=[origin_lat, origin_lon], zoom_start=13)

    # Add a marker for the origin station
    folium.Marker(
        location=[origin_lat, origin_lon],
        popup=f"Origin: {origin_name}",
        icon=folium.Icon(color='blue')
    ).add_to(m)

    # Add markers for the top destinations
    for dest_id, count in grouped_origin_df.size().sort_values(ascending=False).head(top_n).items():
        # Get destination station information
        dest_df = station_df[station_df["Complex ID"] == dest_id]
        dest_lat = dest_df["Latitude"]
        dest_lon = dest_df["Longitude"]
        dest_name = dest_df["Stop Name"]
        
        # Add a marker for the destination station
        folium.Marker(
            location=[dest_lat, dest_lon],
            popup=f"Destination: {dest_name} (Ridership: {count})",
            icon=folium.Icon(color='red')
        ).add_to(m)

    return m

# %%
# Visualize the top n destinations from given station
origin_destination_visualizer(307, top_n=10)
# Out:
# /root/miniconda3/envs/train_data/lib/python3.13/site-packages/folium/utilities.py:69: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(coord)
# /root/miniconda3/envs/train_data/lib/python3.13/site-packages/folium/utilities.py:77: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   if math.isnan(float(coord)):
# /root/miniconda3/envs/train_data/lib/python3.13/site-packages/folium/utilities.py:79: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return [float(x) for x in coords]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b0c7674f77700c42ddd9af2d84ce5049 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b0c7674f77700c42ddd9af2d84ce5049&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b0c7674f77700c42ddd9af2d84ce5049 = L.map(
#                 &quot;map_b0c7674f77700c42ddd9af2d84ce5049&quot;,
#                 {
#                     center: [40.807722, -73.96411],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_08be9eafd8a1ab8b9cc591df49d7a214 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b0c7674f77700c42ddd9af2d84ce5049);
#
#
#             var marker_5a83e08a4a716f2c1e90b1a7730a17e1 = L.marker(
#                 [40.807722, -73.96411],
#                 {}
#             ).addTo(map_b0c7674f77700c42ddd9af2d84ce5049);
#
#
#             var icon_68c1b5628774a73aaf973ae0926c569f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5a83e08a4a716f2c1e90b1a7730a17e1.setIcon(icon_68c1b5628774a73aaf973ae0926c569f);
#
#
#         var popup_b0036ea72109b71a74a70801eff7ec8b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ff2cf4625188079b14a95310da7d6629 = $(`&lt;div id=&quot;html_ff2cf4625188079b14a95310da7d6629&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Origin: 116 St-Columbia University (1)&lt;/div&gt;`)[0];
#                 popup_b0036ea72109b71a74a70801eff7ec8b.setContent(html_ff2cf4625188079b14a95310da7d6629);
#
#
#
#         marker_5a83e08a4a716f2c1e90b1a7730a17e1.bindPopup(popup_b0036ea72109b71a74a70801eff7ec8b)
#         ;
#
#
#
#
#             var marker_e4e661cbef91ad0bfdb2aa5b943b08fc = L.marker(
#                 [40.692259, -73.986642],
#                 {}
#             ).addTo(map_b0c7674f77700c42ddd9af2d84ce5049);
#
#
#             var icon_74c32a92eba0ae86612fe9baae634b0b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e4e661cbef91ad0bfdb2aa5b943b08fc.setIcon(icon_74c32a92eba0ae86612fe9baae634b0b);
#
#
#         var popup_d67971d853692e36eac3e44bff4f6ccd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c176630dd7f6c05d462a03b385629671 = $(`&lt;div id=&quot;html_c176630dd7f6c05d462a03b385629671&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Destination: 111    Jay St-MetroTech Name: Stop Name, dtype: object (Ridership: 21)&lt;/div&gt;`)[0];
#                 popup_d67971d853692e36eac3e44bff4f6ccd.setContent(html_c176630dd7f6c05d462a03b385629671);
#
#
#
#         marker_e4e661cbef91ad0bfdb2aa5b943b08fc.bindPopup(popup_d67971d853692e36eac3e44bff4f6ccd)
#         ;
#
#
#
#
#             var marker_d62d1952be53f81d8494db154ae1b3a8 = L.marker(
#                 [40.746746, -73.891366],
#                 {}
#             ).addTo(map_b0c7674f77700c42ddd9af2d84ce5049);
#
#
#             var icon_1da4151bcd1b7fbffcff6db4ad101758 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d62d1952be53f81d8494db154ae1b3a8.setIcon(icon_1da4151bcd1b7fbffcff6db4ad101758);
#
#
#         var popup_5183421926e181f442adb010ad4fc38d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5040584d01bb7a8e3b77cc0a265547c9 = $(`&lt;div id=&quot;html_5040584d01bb7a8e3b77cc0a265547c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Destination: 95    Jackson Hts-Roosevelt Av/74 St-Broadway Name: Stop Name, dtype: object (Ridership: 21)&lt;/div&gt;`)[0];
#                 popup_5183421926e181f442adb010ad4fc38d.setContent(html_5040584d01bb7a8e3b77cc0a265547c9);
#
#
#
#         marker_d62d1952be53f81d8494db154ae1b3a8.bindPopup(popup_5183421926e181f442adb010ad4fc38d)
#         ;
#
#
#
#
#             var marker_92a4e42f8e486025d596bb37562feeb5 = L.marker(
#                 [40.7682715, -73.9818325],
#                 {}
#             ).addTo(map_b0c7674f77700c42ddd9af2d84ce5049
