# %% [markdown]
# # Explore Hunter and NYU
#
# `datasets/MTA_Subway_Origin-Destination_2024_Hunter_Origin.csv`
# * Full MTA Subway Origin-Destination 2024 Dataset queried for Hunter College Origin Station
#
# `datasets/MTA_Subway_Origin-Destination_2024_NYU_Origin.csv`
# * Full MTA Subway Origin-Destination 2024 Dataset queried for NYU Origin Station

# %%
import pandas as pd

hunter_origin_df = pd.read_csv("datasets/MTA_Subway_Origin-Destination_2024_Hunter_Origin.csv")
nyu_origin_df = pd.read_csv("datasets/MTA_Subway_Origin-Destination_2024_NYU_Origin.csv")

# %%
# Helper functions

import folium

def top_station_destinations(ridership_df, top_n=5):
    top_destinations = ridership_df.groupby("Destination Station Complex Name").size().reset_index(name='Count').sort_values('Count', ascending=False).head(top_n)
    return top_destinations

def origin_destination_visualizer(ridership_df, station_df, top_n = 5):

    # Get ridership data for the origin station and group by destination
    grouped_ridership_df = ridership_df.groupby("Destination Station Complex ID")

    # Get origin station information
    origin_station = ridership_df.iloc[0]
    origin_lat = origin_station["Origin Latitude"]
    origin_lon = origin_station["Origin Longitude"]
    origin_name = origin_station["Origin Station Complex Name"]

    # Create a Folium map centered at the origin station
    m = folium.Map(location=[origin_lat, origin_lon], zoom_start=13)

    # Add a marker for the origin station
    folium.Marker(
        location=[origin_lat, origin_lon],
        popup=f"Origin: {origin_name}",
        icon=folium.Icon(color='blue')
    ).add_to(m)

    # Add markers for the top destinations
    for dest_id, count in grouped_ridership_df.size().sort_values(ascending=False).head(top_n).items():
        # Get destination station information
        dest_df = station_df[station_df["Complex ID"] == dest_id]
        dest_lat = dest_df["Latitude"]
        dest_lon = dest_df["Longitude"]
        dest_name = dest_df["Stop Name"]
        
        # Add a marker for the destination station
        folium.Marker(
            location=[dest_lat, dest_lon],
            popup=f"Destination: {dest_name} (Ridership: {count})",
            icon=folium.Icon(color='red')
        ).add_to(m)

    return m

station_df = pd.read_csv("datasets/MTA_Subway_Stations_and_Complexes_20250225.csv")

# %% [markdown]
# ## Hunter College Exploration and Visualization

# %%
hunter_origin_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450547 entries, 0 to 450546
# Data columns (total 16 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   Year                              450547 non-null  int64
#  1   Month                             450547 non-null  int64
#  2   Day of Week                       450547 non-null  object
#  3   Hour of Day                       450547 non-null  int64
#  4   Timestamp                         450547 non-null  object
#  5   Origin Station Complex ID         450547 non-null  int64
#  6   Origin Station Complex Name       450547 non-null  object
#  7   Origin Latitude                   450547 non-null  float64
#  8   Origin Longitude                  450547 non-null  float64
#  9   Destination Station Complex ID    450547 non-null  int64
#  10  Destination Station Complex Name  450547 non-null  object
#  11  Destination Latitude              450547 non-null  float64
#  12  Destination Longitude             450547 non-null  float64
#  13  Estimated Average Ridership       450547 non-null  float64
#  14  Origin Point                      450547 non-null  object
#  15  Destination Point                 450547 non-null  object
# dtypes: float64(5), int64(5), object(6)
# memory usage: 55.0+ MB

# %%
top_station_destinations(hunter_origin_df, 5)
# Out:
#        Destination Station Complex Name  Count
# 279     Grand Central-42 St (S,4,5,6,7)   1946
# 18                       125 St (4,5,6)   1878
# 137                       86 St (4,5,6)   1872
# 319  Lexington Av-53 St (E,M)/51 St (6)   1845
# 357                     Parkchester (6)   1842

# %%
origin_destination_visualizer(hunter_origin_df, station_df, 5)
# Out:
# /root/miniconda3/envs/train_data/lib/python3.13/site-packages/folium/utilities.py:69: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(coord)
# /root/miniconda3/envs/train_data/lib/python3.13/site-packages/folium/utilities.py:77: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   if math.isnan(float(coord)):
# /root/miniconda3/envs/train_data/lib/python3.13/site-packages/folium/utilities.py:79: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return [float(x) for x in coords]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_db950e9fb0a6dc476b17d23807c5a8f1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_db950e9fb0a6dc476b17d23807c5a8f1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_db950e9fb0a6dc476b17d23807c5a8f1 = L.map(
#                 &quot;map_db950e9fb0a6dc476b17d23807c5a8f1&quot;,
#                 {
#                     center: [40.768141, -73.96387],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a51eec5e6e4e5e2b0f2776cd6808f0d0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_db950e9fb0a6dc476b17d23807c5a8f1);
#
#
#             var marker_339fe5f220f4b6baa1f6fe71460fc4a0 = L.marker(
#                 [40.768141, -73.96387],
#                 {}
#             ).addTo(map_db950e9fb0a6dc476b17d23807c5a8f1);
#
#
#             var icon_3943d824a4550bb206873fa4e3852a60 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_339fe5f220f4b6baa1f6fe71460fc4a0.setIcon(icon_3943d824a4550bb206873fa4e3852a60);
#
#
#         var popup_c54fc37b3823edbf5956d9348b2387c7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d85547104da788ad0f6217b88ed8cd53 = $(`&lt;div id=&quot;html_d85547104da788ad0f6217b88ed8cd53&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Origin: 68 St-Hunter College (6)&lt;/div&gt;`)[0];
#                 popup_c54fc37b3823edbf5956d9348b2387c7.setContent(html_d85547104da788ad0f6217b88ed8cd53);
#
#
#
#         marker_339fe5f220f4b6baa1f6fe71460fc4a0.bindPopup(popup_c54fc37b3823edbf5956d9348b2387c7)
#         ;
#
#
#
#
#             var marker_47004fbef2a91c2153d13e89dd83c81d = L.marker(
#                 [40.751992, -73.97735933],
#                 {}
#             ).addTo(map_db950e9fb0a6dc476b17d23807c5a8f1);
#
#
#             var icon_dd0f9be435f1708492bba57ddeadaf50 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_47004fbef2a91c2153d13e89dd83c81d.setIcon(icon_dd0f9be435f1708492bba57ddeadaf50);
#
#
#         var popup_ac0eed71c36efc7ac26d2783acb83a4f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b819dde923f0d0b05833bf3297596b51 = $(`&lt;div id=&quot;html_b819dde923f0d0b05833bf3297596b51&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Destination: 89    Grand Central-42 St Name: Stop Name, dtype: object (Ridership: 1946)&lt;/div&gt;`)[0];
#                 popup_ac0eed71c36efc7ac26d2783acb83a4f.setContent(html_b819dde923f0d0b05833bf3297596b51);
#
#
#
#         marker_47004fbef2a91c2153d13e89dd83c81d.bindPopup(popup_ac0eed71c36efc7ac26d2783acb83a4f)
#         ;
#
#
#
#
#             var marker_dbdf342dbdeaacec87b486d1b0413685 = L.marker(
#                 [40.804138, -73.937594],
#                 {}
#             ).addTo(map_db950e9fb0a6dc476b17d23807c5a8f1);
#
#
#             var icon_6ef5178716d4ce14513647466601b0e3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_dbdf342dbdeaacec87b486d1b0413685.setIcon(icon_6ef5178716d4ce14513647466601b0e3);
#
#
#         var popup_ec1d0bb908b8c9fd22cc3833a17ac1f9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f7d4b984708b736e7fe967bb50ec8e68 = $(`&lt;div id=&quot;html_f7d4b984708b736e7fe967bb50ec8e68&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Destination: 217    125 St Name: Stop Name, dtype: object (Ridership: 1878)&lt;/div&gt;`)[0];
#                 popup_ec1d0bb908b8c9fd22cc3833a17ac1f9.setContent(html_f7d4b984708b736e7fe967bb50ec8e68);
#
#
#
#         marker_dbdf342dbdeaacec87b486d1b0413685.bindPopup(popup_ec1d0bb908b8c9fd22cc3833a17ac1f9)
#         ;
#
#
#
#
#             var marker_5bb5b2e8c21c5866f91cf9da9cccff02 = L.marker(
#                 [40.779492, -73.955589],
#                 {}
#             ).addTo(map_db950e9fb0a6dc476b17d23807c5a8f1);
#
#
#             var

# %% [markdown]
# ## NYU Exploration and Visualization

# %%
nyu_origin_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406202 entries, 0 to 406201
# Data columns (total 16 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   Year                              406202 non-null  int64
#  1   Month                             406202 non-null  int64
#  2   Day of Week                       406202 non-null  object
#  3   Hour of Day                       406202 non-null  int64
#  4   Timestamp                         406202 non-null  object
#  5   Origin Station Complex ID         406202 non-null  int64
#  6   Origin Station Complex Name       406202 non-null  object
#  7   Origin Latitude                   406202 non-null  float64
#  8   Origin Longitude                  406202 non-null  float64
#  9   Destination Station Complex ID    406202 non-null  int64
#  10  Destination Station Complex Name  406202 non-null  object
#  11  Destination Latitude              406202 non-null  float64
#  12  Destination Longitude             406202 non-null  float64
#  13  Estimated Average Ridership       406202 non-null  float64
#  14  Origin Point                      406202 non-null  object
#  15  Destination Point                 406202 non-null  object
# dtypes: float64(5), int64(5), object(6)
# memory usage: 49.6+ MB

# %%
top_station_destinations(nyu_origin_df, 5)
# Out:
#                      Destination Station Complex Name  Count
# 398  Times Sq-42 St (N,Q,R,W,S,1,2,3,7)/42 St (A,C,E)   2148
# 85                  34 St-Herald Sq (B,D,F,M,N,Q,R,W)   2104
# 99                                      49 St (N,R,W)   2037
# 26                   14 St-Union Sq (L,N,Q,R,W,4,5,6)   2006
# 88                         34 St-Penn Station (A,C,E)   1995

# %%
origin_destination_visualizer(nyu_origin_df, station_df, 5)
# Out:
# /root/miniconda3/envs/train_data/lib/python3.13/site-packages/folium/utilities.py:69: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(coord)
# /root/miniconda3/envs/train_data/lib/python3.13/site-packages/folium/utilities.py:77: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   if math.isnan(float(coord)):
# /root/miniconda3/envs/train_data/lib/python3.13/site-packages/folium/utilities.py:79: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return [float(x) for x in coords]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f0d0e4a3df20b57292196dd34a9b842a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f0d0e4a3df20b57292196dd34a9b842a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f0d0e4a3df20b57292196dd34a9b842a = L.map(
#                 &quot;map_f0d0e4a3df20b57292196dd34a9b842a&quot;,
#                 {
#                     center: [40.730328, -73.992629],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dffc094bc5d5d8bf13021e1fb999632b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f0d0e4a3df20b57292196dd34a9b842a);
#
#
#             var marker_fc2bf707f54a192fd82bb5f988b25dba = L.marker(
#                 [40.730328, -73.992629],
#                 {}
#             ).addTo(map_f0d0e4a3df20b57292196dd34a9b842a);
#
#
#             var icon_16438d307e9b1b9ea9d385b569d4fe10 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fc2bf707f54a192fd82bb5f988b25dba.setIcon(icon_16438d307e9b1b9ea9d385b569d4fe10);
#
#
#         var popup_efe9afbc99083fe2bdecba5e1636daec = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4b58a6e46c0253cca74033686acd8227 = $(`&lt;div id=&quot;html_4b58a6e46c0253cca74033686acd8227&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Origin: 8 St-NYU (R,W)&lt;/div&gt;`)[0];
#                 popup_efe9afbc99083fe2bdecba5e1636daec.setContent(html_4b58a6e46c0253cca74033686acd8227);
#
#
#
#         marker_fc2bf707f54a192fd82bb5f988b25dba.bindPopup(popup_efe9afbc99083fe2bdecba5e1636daec)
#         ;
#
#
#
#
#             var marker_71944a025582e2df954051fbbd4108cf = L.marker(
#                 [40.755746, -73.9875808],
#                 {}
#             ).addTo(map_f0d0e4a3df20b57292196dd34a9b842a);
#
#
#             var icon_9b7594f4d012d89d7ee82dd811f98ccb = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_71944a025582e2df954051fbbd4108cf.setIcon(icon_9b7594f4d012d89d7ee82dd811f98ccb);
#
#
#         var popup_79c98f182d8c974c03f5062633b85902 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fe4d3770eab5a421bb990b4b20e740b4 = $(`&lt;div id=&quot;html_fe4d3770eab5a421bb990b4b20e740b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Destination: 90    Times Sq-42 St/Port Authority Bus Terminal Name: Stop Name, dtype: object (Ridership: 2148)&lt;/div&gt;`)[0];
#                 popup_79c98f182d8c974c03f5062633b85902.setContent(html_fe4d3770eab5a421bb990b4b20e740b4);
#
#
#
#         marker_71944a025582e2df954051fbbd4108cf.bindPopup(popup_79c98f182d8c974c03f5062633b85902)
#         ;
#
#
#
#
#             var marker_72a335af660b559621f58adc053c40e0 = L.marker(
#                 [40.749643, -73.9878865],
#                 {}
#             ).addTo(map_f0d0e4a3df20b57292196dd34a9b842a);
#
#
#             var icon_eaf306ca2dc90a71491156071b95a41c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_72a335af660b559621f58adc053c40e0.setIcon(icon_eaf306ca2dc90a71491156071b95a41c);
#
#
#         var popup_95564d65ac5ff37a6322fa6f50476f36 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_60cfa3ab47292da2eb850498ab837470 = $(`&lt;div id=&quot;html_60cfa3ab47292da2eb850498ab837470&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Destination: 86    34 St-Herald Sq Name: Stop Name, dtype: object (Ridership: 2104)&lt;/div&gt;`)[0];
#                 popup_95564d65ac5ff37a6322fa6f50476f36.setContent(html_60cfa3ab47292da2eb850498ab837470);
#
#
#
#         marker_72a335af660b559621f58adc053c40e0.bindPopup(popup_95564d65ac5ff37a6322fa6f50476f36)
#         ;
#
#
#
#
#             var marker_d6a30c2ad89e78198a5a396f85e4d5b8 = L.marker(
#                 [40.759901, -73.984139],
#                 {}
#             ).addTo(map_f0d0e4a3df20b57292196dd34a9b842a);
