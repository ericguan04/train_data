# %% [markdown]
# # Explore Hunter and NYU
#
# `datasets/MTA_Subway_Origin-Destination_2024_Hunter_Origin.csv`
# * Full MTA Subway Origin-Destination 2024 Dataset queried for Hunter College Origin Station
#
# `datasets/MTA_Subway_Origin-Destination_2024_NYU_Origin.csv`
# * Full MTA Subway Origin-Destination 2024 Dataset queried for NYU Origin Station

# %%
import pandas as pd

hunter_origin_df = pd.read_csv("datasets/MTA_Subway_Origin-Destination_2024_Hunter_Origin.csv")
nyu_origin_df = pd.read_csv("datasets/MTA_Subway_Origin-Destination_2024_NYU_Origin.csv")

# %%
# Helper functions

import folium

def top_station_destinations(ridership_df, top_n=5):
    top_destinations = ridership_df.groupby("Destination Station Complex Name").size().reset_index(name='Count').sort_values('Count', ascending=False).head(top_n)
    return top_destinations

def origin_destination_visualizer(ridership_df, station_df, top_n = 5):

    # Get ridership data for the origin station and group by destination
    grouped_ridership_df = ridership_df.groupby("Destination Station Complex ID")

    # Get origin station information
    origin_station = ridership_df.iloc[0]
    origin_lat = origin_station["Origin Latitude"]
    origin_lon = origin_station["Origin Longitude"]
    origin_name = origin_station["Origin Station Complex Name"]

    # Create a Folium map centered at the origin station
    m = folium.Map(location=[origin_lat, origin_lon], zoom_start=13)

    # Add a marker for the origin station
    folium.Marker(
        location=[origin_lat, origin_lon],
        popup=f"Origin: {origin_name}",
        icon=folium.Icon(color='blue')
    ).add_to(m)

    # Add markers for the top destinations
    for dest_id, count in grouped_ridership_df.size().sort_values(ascending=False).head(top_n).items():
        # Get destination station information
        dest_df = station_df[station_df["Complex ID"] == dest_id]
        dest_lat = dest_df["Latitude"]
        dest_lon = dest_df["Longitude"]
        dest_name = dest_df["Stop Name"]
        
        # Add a marker for the destination station
        folium.Marker(
            location=[dest_lat, dest_lon],
            popup=f"Destination: {dest_name} (Ridership: {count})",
            icon=folium.Icon(color='red')
        ).add_to(m)

    return m

station_df = pd.read_csv("datasets/MTA_Subway_Stations_and_Complexes_20250225.csv")

# %% [markdown]
# ## Hunter College Exploration and Visualization

# %%
hunter_origin_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450547 entries, 0 to 450546
# Data columns (total 16 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   Year                              450547 non-null  int64
#  1   Month                             450547 non-null  int64
#  2   Day of Week                       450547 non-null  object
#  3   Hour of Day                       450547 non-null  int64
#  4   Timestamp                         450547 non-null  object
#  5   Origin Station Complex ID         450547 non-null  int64
#  6   Origin Station Complex Name       450547 non-null  object
#  7   Origin Latitude                   450547 non-null  float64
#  8   Origin Longitude                  450547 non-null  float64
#  9   Destination Station Complex ID    450547 non-null  int64
#  10  Destination Station Complex Name  450547 non-null  object
#  11  Destination Latitude              450547 non-null  float64
#  12  Destination Longitude             450547 non-null  float64
#  13  Estimated Average Ridership       450547 non-null  float64
#  14  Origin Point                      450547 non-null  object
#  15  Destination Point                 450547 non-null  object
# dtypes: float64(5), int64(5), object(6)
# memory usage: 55.0+ MB

# %%
top_station_destinations(hunter_origin_df, 5)
# Out:
#        Destination Station Complex Name  Count
# 279     Grand Central-42 St (S,4,5,6,7)   1946
# 18                       125 St (4,5,6)   1878
# 137                       86 St (4,5,6)   1872
# 319  Lexington Av-53 St (E,M)/51 St (6)   1845
# 357                     Parkchester (6)   1842

# %%
origin_destination_visualizer(hunter_origin_df, station_df, 5)
# Out:
# /root/miniconda3/envs/train_data/lib/python3.13/site-packages/folium/utilities.py:69: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(coord)
# /root/miniconda3/envs/train_data/lib/python3.13/site-packages/folium/utilities.py:77: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   if math.isnan(float(coord)):
# /root/miniconda3/envs/train_data/lib/python3.13/site-packages/folium/utilities.py:79: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return [float(x) for x in coords]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_22060d56ebc6c21acdd20ffe14fbf095 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_22060d56ebc6c21acdd20ffe14fbf095&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_22060d56ebc6c21acdd20ffe14fbf095 = L.map(
#                 &quot;map_22060d56ebc6c21acdd20ffe14fbf095&quot;,
#                 {
#                     center: [40.768141, -73.96387],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8fc316892f11728cce802bfa3b60ac83 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_22060d56ebc6c21acdd20ffe14fbf095);
#
#
#             var marker_6cd6af9516564322e3b6e698a523ecc6 = L.marker(
#                 [40.768141, -73.96387],
#                 {}
#             ).addTo(map_22060d56ebc6c21acdd20ffe14fbf095);
#
#
#             var icon_5b558e38400e97bb34501da66ee13fc1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6cd6af9516564322e3b6e698a523ecc6.setIcon(icon_5b558e38400e97bb34501da66ee13fc1);
#
#
#         var popup_0a049d24fd2ea866b9a78aa035f1c1e1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8610b647d8582f2c08f995a652c7b3ef = $(`&lt;div id=&quot;html_8610b647d8582f2c08f995a652c7b3ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Origin: 68 St-Hunter College (6)&lt;/div&gt;`)[0];
#                 popup_0a049d24fd2ea866b9a78aa035f1c1e1.setContent(html_8610b647d8582f2c08f995a652c7b3ef);
#
#
#
#         marker_6cd6af9516564322e3b6e698a523ecc6.bindPopup(popup_0a049d24fd2ea866b9a78aa035f1c1e1)
#         ;
#
#
#
#
#             var marker_fc5bd24367eae39b1a00eb888df7ab50 = L.marker(
#                 [40.751992, -73.97735933],
#                 {}
#             ).addTo(map_22060d56ebc6c21acdd20ffe14fbf095);
#
#
#             var icon_55ec49068f0d0e8ab18e2b2da44f9ca1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fc5bd24367eae39b1a00eb888df7ab50.setIcon(icon_55ec49068f0d0e8ab18e2b2da44f9ca1);
#
#
#         var popup_e6a541960c50b490c4931240150c4768 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1f5edc474e8a5335ac16cb7ed141ad5d = $(`&lt;div id=&quot;html_1f5edc474e8a5335ac16cb7ed141ad5d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Destination: 89    Grand Central-42 St Name: Stop Name, dtype: object (Ridership: 1946)&lt;/div&gt;`)[0];
#                 popup_e6a541960c50b490c4931240150c4768.setContent(html_1f5edc474e8a5335ac16cb7ed141ad5d);
#
#
#
#         marker_fc5bd24367eae39b1a00eb888df7ab50.bindPopup(popup_e6a541960c50b490c4931240150c4768)
#         ;
#
#
#
#
#             var marker_44c0310bbf5db5db413464315b3a9fff = L.marker(
#                 [40.804138, -73.937594],
#                 {}
#             ).addTo(map_22060d56ebc6c21acdd20ffe14fbf095);
#
#
#             var icon_e5701b2c11c41a1a51844e7dc50b8ae8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_44c0310bbf5db5db413464315b3a9fff.setIcon(icon_e5701b2c11c41a1a51844e7dc50b8ae8);
#
#
#         var popup_67fbb0078210c2a3c60ed698a16bcee4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f95b57d354cf18ddcccc111616fd7bf7 = $(`&lt;div id=&quot;html_f95b57d354cf18ddcccc111616fd7bf7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Destination: 217    125 St Name: Stop Name, dtype: object (Ridership: 1878)&lt;/div&gt;`)[0];
#                 popup_67fbb0078210c2a3c60ed698a16bcee4.setContent(html_f95b57d354cf18ddcccc111616fd7bf7);
#
#
#
#         marker_44c0310bbf5db5db413464315b3a9fff.bindPopup(popup_67fbb0078210c2a3c60ed698a16bcee4)
#         ;
#
#
#
#
#             var marker_035980def289743dc236cfdde43f246b = L.marker(
#                 [40.779492, -73.955589],
#                 {}
#             ).addTo(map_22060d56ebc6c21acdd20ffe14fbf095);
#
#
#             var

# %% [markdown]
# ## NYU Exploration and Visualization

# %%
nyu_origin_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406202 entries, 0 to 406201
# Data columns (total 16 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   Year                              406202 non-null  int64
#  1   Month                             406202 non-null  int64
#  2   Day of Week                       406202 non-null  object
#  3   Hour of Day                       406202 non-null  int64
#  4   Timestamp                         406202 non-null  object
#  5   Origin Station Complex ID         406202 non-null  int64
#  6   Origin Station Complex Name       406202 non-null  object
#  7   Origin Latitude                   406202 non-null  float64
#  8   Origin Longitude                  406202 non-null  float64
#  9   Destination Station Complex ID    406202 non-null  int64
#  10  Destination Station Complex Name  406202 non-null  object
#  11  Destination Latitude              406202 non-null  float64
#  12  Destination Longitude             406202 non-null  float64
#  13  Estimated Average Ridership       406202 non-null  float64
#  14  Origin Point                      406202 non-null  object
#  15  Destination Point                 406202 non-null  object
# dtypes: float64(5), int64(5), object(6)
# memory usage: 49.6+ MB

# %%
top_station_destinations(nyu_origin_df, 5)
# Out:
#                      Destination Station Complex Name  Count
# 398  Times Sq-42 St (N,Q,R,W,S,1,2,3,7)/42 St (A,C,E)   2148
# 85                  34 St-Herald Sq (B,D,F,M,N,Q,R,W)   2104
# 99                                      49 St (N,R,W)   2037
# 26                   14 St-Union Sq (L,N,Q,R,W,4,5,6)   2006
# 88                         34 St-Penn Station (A,C,E)   1995

# %%
origin_destination_visualizer(nyu_origin_df, station_df, 5)
# Out:
# /root/miniconda3/envs/train_data/lib/python3.13/site-packages/folium/utilities.py:69: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(coord)
# /root/miniconda3/envs/train_data/lib/python3.13/site-packages/folium/utilities.py:77: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   if math.isnan(float(coord)):
# /root/miniconda3/envs/train_data/lib/python3.13/site-packages/folium/utilities.py:79: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return [float(x) for x in coords]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a841c03e62bb748fb30d672926da40ff {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a841c03e62bb748fb30d672926da40ff&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a841c03e62bb748fb30d672926da40ff = L.map(
#                 &quot;map_a841c03e62bb748fb30d672926da40ff&quot;,
#                 {
#                     center: [40.730328, -73.992629],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_618a158bac80f94b26815a3068723a03 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a841c03e62bb748fb30d672926da40ff);
#
#
#             var marker_d04b27c3ba9b01c3b2d3601439c38b67 = L.marker(
#                 [40.730328, -73.992629],
#                 {}
#             ).addTo(map_a841c03e62bb748fb30d672926da40ff);
#
#
#             var icon_cda4a4c6542b17d282eca3f59015c36c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d04b27c3ba9b01c3b2d3601439c38b67.setIcon(icon_cda4a4c6542b17d282eca3f59015c36c);
#
#
#         var popup_5e91b0da24479845aa4809a698b69e72 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d3704fd89657720adfe532911168df13 = $(`&lt;div id=&quot;html_d3704fd89657720adfe532911168df13&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Origin: 8 St-NYU (R,W)&lt;/div&gt;`)[0];
#                 popup_5e91b0da24479845aa4809a698b69e72.setContent(html_d3704fd89657720adfe532911168df13);
#
#
#
#         marker_d04b27c3ba9b01c3b2d3601439c38b67.bindPopup(popup_5e91b0da24479845aa4809a698b69e72)
#         ;
#
#
#
#
#             var marker_e9780bc88ee5387bf8becffe67668991 = L.marker(
#                 [40.755746, -73.9875808],
#                 {}
#             ).addTo(map_a841c03e62bb748fb30d672926da40ff);
#
#
#             var icon_3c3fc6f6f3762ca6465a713abfe1fbbf = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e9780bc88ee5387bf8becffe67668991.setIcon(icon_3c3fc6f6f3762ca6465a713abfe1fbbf);
#
#
#         var popup_11e900f4a8b8c20c1bb3ddb68c587b41 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d70f8f78a4978799d62ba70483084a61 = $(`&lt;div id=&quot;html_d70f8f78a4978799d62ba70483084a61&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Destination: 90    Times Sq-42 St/Port Authority Bus Terminal Name: Stop Name, dtype: object (Ridership: 2148)&lt;/div&gt;`)[0];
#                 popup_11e900f4a8b8c20c1bb3ddb68c587b41.setContent(html_d70f8f78a4978799d62ba70483084a61);
#
#
#
#         marker_e9780bc88ee5387bf8becffe67668991.bindPopup(popup_11e900f4a8b8c20c1bb3ddb68c587b41)
#         ;
#
#
#
#
#             var marker_d0cdc23438e06dc67651440d76be05ee = L.marker(
#                 [40.749643, -73.9878865],
#                 {}
#             ).addTo(map_a841c03e62bb748fb30d672926da40ff);
#
#
#             var icon_86fd6762c62d008c6dba8c717d153d7c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d0cdc23438e06dc67651440d76be05ee.setIcon(icon_86fd6762c62d008c6dba8c717d153d7c);
#
#
#         var popup_9d320eceaf3152197b3250f3794cb101 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_299099bc67a177d15c3a4a92d731feb9 = $(`&lt;div id=&quot;html_299099bc67a177d15c3a4a92d731feb9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Destination: 86    34 St-Herald Sq Name: Stop Name, dtype: object (Ridership: 2104)&lt;/div&gt;`)[0];
#                 popup_9d320eceaf3152197b3250f3794cb101.setContent(html_299099bc67a177d15c3a4a92d731feb9);
#
#
#
#         marker_d0cdc23438e06dc67651440d76be05ee.bindPopup(popup_9d320eceaf3152197b3250f3794cb101)
#         ;
#
#
#
#
#             var marker_fe593cf7e30b14ede0c90ead2d2837e5 = L.marker(
#                 [40.759901, -73.984139],
#                 {}
#             ).addTo(map_a841c03e62bb748fb30d672926da40ff);

# %%
hunter_origin_df_grouped = hunter_origin_df.groupby(["Destination Station Complex ID", "Destination Station Complex Name"]).size().reset_index(name='Count')
hunter_origin_df_grouped
# Out:
#      Destination Station Complex ID    Destination Station Complex Name  Count
# 0                                 1          Astoria-Ditmars Blvd (N,W)   1513
# 1                                 2                  Astoria Blvd (N,W)   1384
# 2                                 3                         30 Av (N,W)   1546
# 3                                 4                      Broadway (N,W)   1500
# 4                                 5                         36 Av (N,W)   1320
# ..                              ...                                 ...    ...
# 415                             628         Fulton St (A,C,J,Z,2,3,4,5)   1800
# 416                             629  Lorimer St (L)/Metropolitan Av (G)   1397
# 417                             630            Myrtle-Wyckoff Avs (L,M)   1441
# 418                             635  South Ferry (1)/Whitehall St (R,W)   1437
# 419                             636          Jay St-MetroTech (A,C,F,R)   1303
#
# [420 rows x 3 columns]

# %%
nyu_origin_df_grouped = nyu_origin_df.groupby(["Destination Station Complex ID", "Destination Station Complex Name"]).size().reset_index(name='Count')
nyu_origin_df_grouped
# Out:
#      Destination Station Complex ID    Destination Station Complex Name  Count
# 0                                 1          Astoria-Ditmars Blvd (N,W)   1842
# 1                                 2                  Astoria Blvd (N,W)   1843
# 2                                 3                         30 Av (N,W)   1861
# 3                                 4                      Broadway (N,W)   1774
# 4                                 5                         36 Av (N,W)   1724
# ..                              ...                                 ...    ...
# 418                             628         Fulton St (A,C,J,Z,2,3,4,5)   1903
# 419                             629  Lorimer St (L)/Metropolitan Av (G)   1487
# 420                             630            Myrtle-Wyckoff Avs (L,M)   1519
# 421                             635  South Ferry (1)/Whitehall St (R,W)   1900
# 422                             636          Jay St-MetroTech (A,C,F,R)   1865
#
# [423 rows x 3 columns]

# %%
hunter_stations_of_interest = hunter_origin_df_grouped[(hunter_origin_df_grouped["Destination Station Complex ID"] == 135) | 
                                                   (hunter_origin_df_grouped["Destination Station Complex ID"] == 209) |
                                                   (hunter_origin_df_grouped["Destination Station Complex ID"] == 196)]

nyu_stations_of_interest = nyu_origin_df_grouped[(nyu_origin_df_grouped["Destination Station Complex ID"] == 135) | 
                                                   (nyu_origin_df_grouped["Destination Station Complex ID"] == 209) |
                                                   (nyu_origin_df_grouped["Destination Station Complex ID"] == 196)]

# %%
hunter_stations_of_interest
# Out:
#      Destination Station Complex ID Destination Station Complex Name  Count
# 107                             135                   Livonia Av (L)    554
# 155                             196           Aqueduct Racetrack (A)    146
# 168                             209         Far Rockaway-Mott Av (A)    761

# %%
nyu_stations_of_interest
# Out:
#      Destination Station Complex ID Destination Station Complex Name  Count
# 106                             135                   Livonia Av (L)    234
# 154                             196           Aqueduct Racetrack (A)     51
# 167                             209         Far Rockaway-Mott Av (A)    190

# %% [markdown]
# Something interseting here is that hunter has a higher destination rate at the high police enforcement stations than nyu
# This can be a useful insight - need to continue testing with the other datasets
